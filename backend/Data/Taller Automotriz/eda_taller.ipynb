# %%
#@title *
HTML('''
<div style="position: relative;">
    <div style="
        background-image: url(
          'https://images.unsplash.com/photo-1583955275036-fd20a9c185bd?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D'
          );
        background-size: cover;
        background-position: center;
        width: 100%;
        height: 300px;
        border-radius: 10px;
        margin: 20px 0;
        box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
    </div>
    <div style="
        position: absolute;
        bottom: 20px;
        left: 20px;
        color: white;
        font-size: 24px;
        text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
        Taller Automotriz
    </div>
</div>
''')
# Out:
# <div style="position: relative;">
#     <div style="
#         background-image: url(
#           'https://images.unsplash.com/photo-1583955275036-fd20a9c185bd?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D'
#           );
#         background-size: cover;
#         background-position: center;
#         width: 100%;
#         height: 300px;
#         border-radius: 10px;
#         margin: 20px 0;
#         box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     </div>
#     <div style="
#         position: absolute;
#         bottom: 20px;
#         left: 20px;
#         color: white;
#         font-size: 24px;
#         text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#         Taller Automotriz
#     </div>
# </div>

# %% [markdown]
# Foto por [Tekton Universal](https://unsplash.com/@tekton_tools) en Unsplash.

# %% [markdown]
# # **Análisis Exploratorio en Taller Automotriz 🚗**

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec ut ultricies dolor, consequat mattis augue. Nam libero metus, condimentum ac sapien non, laoreet varius nisi. Nullam et tristique elit, non varius enim. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Duis et dictum ipsum. Morbi fermentum pellentesque maximus. Praesent vestibulum sit amet justo vel scelerisque. Etiam vel imperdiet urna. Sed rhoncus turpis in elit sagittis semper. Pellentesque congue, turpis in hendrerit interdum, justo lectus porta elit, id fringilla sapien felis ac orci. Proin posuere posuere mauris accumsan condimentum. Morbi laoreet enim lacus, id lacinia leo mollis a. Suspendisse quis venenatis felis, vel semper mi. Sed laoreet mi vitae gravida gravida. Nullam ultrices volutpat mi ac pharetra.

# %% [markdown]
# **Autores:**
# - [Andrea Ramírez](https://github.com/Andrea-gt)

# %% [markdown]
# ***

# %% [markdown]
# ## **(1) Importación de Librerías** ⬇️

# %%
# ===== Standard Libraries =====
import os  # For operating system utilities
import warnings  # For warning management

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# ===== Data Manipulation and Analysis =====
import numpy as np  # For numerical computations
import pandas as pd  # For data manipulation and analysis

# ===== Visualization =====
import matplotlib.pyplot as plt  # For basic plotting
import seaborn as sns  # For enhanced data visualization
from IPython.display import Image  # For displaying images in Jupyter Notebooks
from IPython.core.display import HTML  # For displaying HTML content

# Set default figure size and style
plt.rcParams['figure.figsize'] = (6, 4)  # Default figure size
plt.rcParams['agg.path.chunksize'] = 10000
sns.set(style="whitegrid")  # Seaborn style for plots

# Define custom color palette
palette = sns.color_palette("viridis", 12)

# Enable inline plotting for Jupyter Notebooks
# %matplotlib inline

# Set a fixed seed for reproducibility
random_state = 42
np.random.seed(random_state)  # Seed for NumPy random functions

# %% [markdown]
# ## **(2) Carga de Datos** 📄

# %%
# Load the dataset into a DataFrame
df = pd.read_csv('data_taller_automotriz.csv' , sep=';' , header=0)  # Read the CSV file as a DataFrame

# Display the first five rows of the DataFrame
df.head()  # Preview the top entries to understand the data structure
# Out:
#    C_VARADO                    CAUSA_VARADO  COD_ACTIVIDAD  COD_ACTIVO  \
# 0       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2451
# 1       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2455
# 2       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2456
# 3       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2457
# 4       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2459
#
#    COD_CATEGORIA  COD_CORRELATIVO  COD_DEPTO  COD_EPOCA  COD_LABOR  \
# 0            245                1         12          1         25
# 1            245                5         10          1         22
# 2            245                6         26          1         22
# 3            245                7         10          1         22
# 4            245                9         10          1         25
#
#    COD_PERIODO  ...  TOT_V  TOT_VC  X1_VARADO NOMBRE_ACTIVIDAD.1  \
# 0           45  ...   0.13    0.13       0.56          TRACTORES
# 1           45  ...   0.00    0.00       0.00          TRACTORES
# 2           43  ...   0.00    0.00       0.00          TRACTORES
# 3           45  ...   0.00    0.00       0.00          TRACTORES
# 4           45  ...   0.00    0.00       0.00          TRACTORES
#
#   NOMBRE_ACTIVIDAD.2  MonthName(MES)                          TALLER.1  \
# 0          TRACTORES       ene. 2023  TALLER COSECHA/MAQUINARIA PESADA
# 1          TRACTORES       nov. 2022  TALLER COSECHA/MAQUINARIA PESADA
# 2          TRACTORES       dic. 2021  TALLER COSECHA/MAQUINARIA PESADA
# 3          TRACTORES       nov. 2022  TALLER COSECHA/MAQUINARIA PESADA
# 4          TRACTORES       nov. 2022  TALLER COSECHA/MAQUINARIA PESADA
#
#   SEMANA.1  Disponibilidad Porc_utilizacion
# 0    SEM 9           99.4%                -
# 1    SEM 1           17.8%                -
# 2    SEM 4           47.6%                -
# 3    SEM 1           17.6%                -
# 4    SEM 1           78.4%                -
#
# [5 rows x 43 columns]

# %% [markdown]
# ## **(3) Análisis Exploratorio** 🔎

# %% [markdown]
# ### **(1) Visualización General y Descripción del Conjunto de Datos**

# %%
# Print the number of records in the DataFrame
print("El conjunto de datos tiene {:,} registros y {:,} columnas.".format(df.shape[0], df.shape[1]))
# Out:
# El conjunto de datos tiene 278,917 registros y 43 columnas.

# %% [markdown]
# **Observaciones 💡 -->**
# > - El conjunto de datos  con el que se está trabajando cuenta con 1,020,775 registros y 43 columnas, lo que indica que se trata de un conjunto de datos con una dimensión relativamente grande y moderadamente detallado.

# %%
# Basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278917 entries, 0 to 278916
# Data columns (total 43 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   C_VARADO            0 non-null       float64
#  1   CAUSA_VARADO        278917 non-null  object
#  2   COD_ACTIVIDAD       278917 non-null  int64
#  3   COD_ACTIVO          278917 non-null  int64
#  4   COD_CATEGORIA       278917 non-null  int64
#  5   COD_CORRELATIVO     278917 non-null  int64
#  6   COD_DEPTO           278917 non-null  int64
#  7   COD_EPOCA           278917 non-null  int64
#  8   COD_LABOR           278917 non-null  int64
#  9   COD_PERIODO         278917 non-null  int64
#  10  COD_SEMANA          278917 non-null  int64
#  11  COD_TALLER          278917 non-null  int64
#  12  COD_TALLER_MATRIZ   278916 non-null  float64
#  13  CORRELATIVO         278916 non-null  object
#  14  DIAS_TRAB           278916 non-null  object
#  15  DISP                278916 non-null  float64
#  16  EPOCA               278916 non-null  object
#  17  FECHA               278916 non-null  object
#  18  HORAS_JORNADA       278916 non-null  float64
#  19  KMS                 278916 non-null  object
#  20  LITERAL             278916 non-null  object
#  21  MES                 278916 non-null  object
#  22  NOMBRE_ACTIVIDAD    278916 non-null  object
#  23  NOMBRE_DEPTO        278916 non-null  object
#  24  NOMBRE_LABOR        278916 non-null  object
#  25  NOMBRE_TALLER       278916 non-null  object
#  26  PERIODO             278916 non-null  object
#  27  SEMANA              278916 non-null  object
#  28  TALLER              278916 non-null  object
#  29  TIEMPO_VARADO       278916 non-null  object
#  30  TIPO_MEDICION       278916 non-null  object
#  31  TOT_C               0 non-null       float64
#  32  TOT_D               278916 non-null  float64
#  33  TOT_V               278916 non-null  float64
#  34  TOT_VC              278916 non-null  float64
#  35  X1_VARADO           278916 non-null  float64
#  36  NOMBRE_ACTIVIDAD.1  278916 non-null  object
#  37  NOMBRE_ACTIVIDAD.2  278916 non-null  object
#  38  MonthName(MES)      278916 non-null  object
#  39  TALLER.1            278916 non-null  object
#  40  SEMANA.1            278916 non-null  object
#  41  Disponibilidad      278916 non-null  object
#  42  Porc_utilizacion    278916 non-null  object
# dtypes: float64(9), int64(10), object(24)
# memory usage: 91.5+ MB

# %% [markdown]
# **Observación 💡 -->**
# La columna `TOT_C` no contiene valores no nulos, lo que indica que no aporta información útil al conjunto de datos. Dado que su inclusión únicamente incrementa la dimensionalidad sin añadir valor analítico, se decide eliminarla.

# %%
# Drop the 'tot_c' column
df = df.drop(columns=['TOT_C'])

# %%
# Transpose the first 3 rows of the DataFrame
# to display column names as rows for better readability.
df.head(3).T
# Out:
#                                                    0  \
# C_VARADO                                         NaN
# CAUSA_VARADO          ACTIVO SIN USO(POCO RECORRIDO)
# COD_ACTIVIDAD                                      3
# COD_ACTIVO                                      2451
# COD_CATEGORIA                                    245
# COD_CORRELATIVO                                    1
# COD_DEPTO                                         12
# COD_EPOCA                                          1
# COD_LABOR                                         25
# COD_PERIODO                                       45
# COD_SEMANA                                         9
# COD_TALLER                                         5
# COD_TALLER_MATRIZ                                2.0
# CORRELATIVO                                        1
# DIAS_TRAB                                          -
# DISP                                          0.9944
# EPOCA                                          ZAFRA
# FECHA                               14/01/2023 00:00
# HORAS_JORNADA                                   24.0
# KMS                                                -
# LITERAL                                            D
# MES                                 31/01/2023 00:00
# NOMBRE_ACTIVIDAD                           TRACTORES
# NOMBRE_DEPTO                                FRENTE G
# NOMBRE_LABOR                        TRACTOR AGUATERO
# NOMBRE_TALLER                    COSECHA GRANEL CANA
# PERIODO                                  ZAFRA 22-23
# SEMANA                                         SEM 9
# TALLER              TALLER COSECHA/MAQUINARIA PESADA
# TIEMPO_VARADO                                   0.13
# TIPO_MEDICION                                      -
# TOT_D                                          23.87
# TOT_V                                           0.13
# TOT_VC                                          0.13
# X1_VARADO                                       0.56
# NOMBRE_ACTIVIDAD.1                         TRACTORES
# NOMBRE_ACTIVIDAD.2                         TRACTORES
# MonthName(MES)                             ene. 2023
# TALLER.1            TALLER COSECHA/MAQUINARIA PESADA
# SEMANA.1                                       SEM 9
# Disponibilidad                                 99.4%
# Porc_utilizacion                                   -
#
#                                                    1  \
# C_VARADO                                         NaN
# CAUSA_VARADO          ACTIVO SIN USO(POCO RECORRIDO)
# COD_ACTIVIDAD                                      3
# COD_ACTIVO                                      2455
# COD_CATEGORIA                                    245
# COD_CORRELATIVO                                    5
# COD_DEPTO                                         10
# COD_EPOCA                                          1
# COD_LABOR                                         22
# COD_PERIODO                                       45
# COD_SEMANA                                         1
# COD_TALLER                                         5
# COD_TALLER_MATRIZ                                2.0
# CORRELATIVO                                        -
# DIAS_TRAB                                          -
# DISP                                          0.1778
# EPOCA                                          ZAFRA
# FECHA                               17/11/2022 00:00
# HORAS_JORNADA                                   24.0
# KMS                                                -
# LITERAL                                            D
# MES                                 30/11/2022 00:00
# NOMBRE_ACTIVIDAD                           TRACTORES
# NOMBRE_DEPTO                                FRENTE C
# NOMBRE_LABOR                        TRACTOR AGRICOLA
# NOMBRE_TALLER                    COSECHA GRANEL CANA
# PERIODO                                  ZAFRA 22-23
# SEMANA                                         SEM 1
# TALLER              TALLER COSECHA/MAQUINARIA PESADA
# TIEMPO_VARADO                                   0.08
# TIPO_MEDICION                                      -
# TOT_D                                           4.27
# TOT_V                                            0.0
# TOT_VC                                           0.0
# X1_VARADO                                        0.0
# NOMBRE_ACTIVIDAD.1                         TRACTORES
# NOMBRE_ACTIVIDAD.2                         TRACTORES
# MonthName(MES)                             nov. 2022
# TALLER.1            TALLER COSECHA/MAQUINARIA PESADA
# SEMANA.1                                       SEM 1
# Disponibilidad                                 17.8%
# Porc_utilizacion                                   -
#
#                                                    2
# C_VARADO                                         NaN
# CAUSA_VARADO          ACTIVO SIN USO(POCO RECORRIDO)
# COD_ACTIVIDAD                                      3
# COD_ACTIVO                                      2456
# COD_CATEGORIA                                    245
# COD_CORRELATIVO                                    6
# COD_DEPTO                                         26
# COD_EPOCA                                          1
# COD_LABOR                                         22
# COD_PERIODO                                       43
# COD_SEMANA                                         4
# COD_TALLER                                         5
# COD_TALLER_MATRIZ                                2.0
# CORRELATIVO                                        -
# DIAS_TRAB                                          -
# DISP                                          0.4764
# EPOCA                                          ZAFRA
# FECHA                               12/12/2021 00:00
# HORAS_JORNADA                                   24.0
# KMS                                                -
# LITERAL                                            D
# MES                                 31/12/2021 00:00
# NOMBRE_ACTIVIDAD                           TRACTORES
# NOMBRE_DEPTO                                PATIO T.
# NOMBRE_LABOR                        TRACTOR AGRICOLA
# NOMBRE_TALLER                    COSECHA GRANEL CANA
# PERIODO                                  ZAFRA 21-22
# SEMANA                                         SEM 4
# TALLER              TALLER COSECHA/MAQUINARIA PESADA
# TIEMPO_VARADO                                   0.02
# TIPO_MEDICION                                      -
# TOT_D                                          11.43
# TOT_V                                            0.0
# TOT_VC                                           0.0
# X1_VARADO                                        0.0
# NOMBRE_ACTIVIDAD.1                         TRACTORES
# NOMBRE_ACTIVIDAD.2                         TRACTORES
# MonthName(MES)                             dic. 2021
# TALLER.1            TALLER COSECHA/MAQUINARIA PESADA
# SEMANA.1                                       SEM 4
# Disponibilidad                                 47.6%
# Porc_utilizacion                                   -

# %% [markdown]
# ### **(2) Exploración y Limpieza Inicial de los Datos**

# %%
# Use a pandas function to rename the current function
df.rename(columns={
    'C_VARADO': 'c_varado',
    'CAUSA_VARADO': 'causa_varado',
    'COD_ACTIVIDAD': 'cod_actividad',
    'COD_ACTIVO': 'cod_activo',
    'COD_CATEGORIA': 'cod_categoria',
    'COD_CORRELATIVO': 'cod_correlativo',
    'COD_DEPTO': 'cod_depto',
    'COD_EPOCA': 'cod_epoca',
    'COD_LABOR': 'cod_labor',
    'COD_PERIODO': 'cod_periodo',
    'COD_SEMANA': 'cod_semana',
    'COD_TALLER': 'cod_taller',
    'COD_TALLER_MATRIZ': 'cod_taller_matriz',
    'CORRELATIVO': 'correlativo',
    'DIAS_TRAB': 'dias_trab',
    'DISP': 'disp',
    'EPOCA': 'epoca',
    'FECHA': 'fecha',
    'HORAS_JORNADA': 'horas_jornada',
    'KMS': 'kms',
    'LITERAL': 'literal',
    'MES': 'mes',
    'NOMBRE_ACTIVIDAD': 'nombre_actividad',
    'NOMBRE_DEPTO': 'nombre_depto',
    'NOMBRE_LABOR': 'nombre_labor',
    'NOMBRE_TALLER': 'nombre_taller',
    'PERIODO': 'periodo',
    'SEMANA': 'semana',
    'TALLER': 'taller',
    'TIEMPO_VARADO': 'tiempo_varado',
    'TIPO_MEDICION': 'tipo_medicion',
    'TOT_D': 'tot_d',
    'TOT_V': 'tot_v',
    'TOT_VC': 'tot_vc',
    'X1_VARADO': 'x1_varado',
    'NOMBRE_ACTIVIDAD.1': 'nombre_actividad_1',
    'NOMBRE_ACTIVIDAD.2': 'nombre_actividad_2',
    'MonthName(MES)': 'mes_nombre',
    'TALLER.1': 'taller_1',
    'SEMANA.1': 'semana_1',
    'Disponibilidad': 'disponibilidad',
    'Porc_utilizacion': 'porc_utilizacion'
}, inplace=True)

# %%
df.head(2)
# Out:
#    c_varado                    causa_varado  cod_actividad  cod_activo  \
# 0       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2451
# 1       NaN  ACTIVO SIN USO(POCO RECORRIDO)              3        2455
#
#    cod_categoria  cod_correlativo  cod_depto  cod_epoca  cod_labor  \
# 0            245                1         12          1         25
# 1            245                5         10          1         22
#
#    cod_periodo  ...  tot_v  tot_vc  x1_varado nombre_actividad_1  \
# 0           45  ...   0.13    0.13       0.56          TRACTORES
# 1           45  ...   0.00    0.00       0.00          TRACTORES
#
#   nombre_actividad_2  mes_nombre                          taller_1 semana_1  \
# 0          TRACTORES   ene. 2023  TALLER COSECHA/MAQUINARIA PESADA    SEM 9
# 1          TRACTORES   nov. 2022  TALLER COSECHA/MAQUINARIA PESADA    SEM 1
#
#    disponibilidad porc_utilizacion
# 0           99.4%                -
# 1           17.8%                -
#
# [2 rows x 42 columns]

# %% [markdown]
# #### **Clasificación de las Variables**

# %% [markdown]
# | **Variable**              | **Tipo**             | **Descripción**                                                              |
# |---------------------------|----------------------|------------------------------------------------------------------------------|
# | `c_varado`                | Categórica           | Identificador del estado de inactividad o "varado."                          |
# | `causa_varado`            | Categórica           | Causa de la inactividad o tiempo de inoperatividad.                          |
# | `cod_actividad`           | Categórica           | Código del tipo de actividad.                                                |
# | `cod_activo`              | Categórica           | Código del activo específico.                                                |
# | `cod_categoria`           | Categórica           | Código de la categoría del activo.                                           |
# | `cod_correlativo`         | Ordinal              | Código secuencial para correlacionar registros.                              |
# | `cod_depto`               | Categórica           | Código del departamento o área.                                              |
# | `cod_epoca`               | Categórica           | Código que representa la época o temporada.                                  |
# | `cod_labor`               | Categórica           | Código del tipo de labor o tarea.                                            |
# | `cod_periodo`             | Categórica           | Código del periodo de operación.                                             |
# | `cod_semana`              | Ordinal              | Código del número de la semana dentro del periodo.                           |
# | `cod_taller`              | Categórica           | Código del taller o instalación específica.                                  |
# | `cod_taller_matriz`       | Categórica           | Código del taller matriz o principal.                                        |
# | `correlativo`             | Ordinal              | Identificador secuencial.                                                    |
# | `dias_trab`               | Numérica (Continua)  | Número de días trabajados.                                                   |
# | `disp`                    | Numérica (Continua)  | Ratio de disponibilidad (en valor decimal).                                  |
# | `epoca`                   | Categórica           | Nombre de la época o temporada (ej.: "ZAFRA").                               |
# | `fecha`                   | Temporal             | Fecha del registro (marca temporal).                                         |
# | `horas_jornada`           | Numérica (Continua)  | Número de horas en una jornada laboral.                                      |
# | `kms`                     | Numérica (Continua)  | Kilómetros recorridos (si aplica).                                           |
# | `literal`                 | Categórica           | Código literal o designación para clasificación.                             |
# | `mes`                     | Temporal             | Mes del registro (marca temporal).                                           |
# | `nombre_actividad`        | Categórica           | Nombre de la actividad realizada.                                            |
# | `nombre_depto`            | Categórica           | Nombre del departamento o área.                                              |
# | `nombre_labor`            | Categórica           | Nombre de la labor o tarea realizada.                                        |
# | `nombre_taller`           | Categórica           | Nombre del taller o instalación específica.                                  |
# | `periodo`                 | Categórica           | Nombre del periodo (ej.: "ZAFRA 22-23").                                     |
# | `semana`                  | Ordinal              | Nombre o identificador de la semana (ej.: "SEM 9").                          |
# | `taller`                  | Categórica           | Descripción del taller o instalación.                                        |
# | `tiempo_varado`           | Numérica (Continua)  | Duración del tiempo de inactividad (en horas).                               |
# | `tipo_medicion`           | Categórica           | Tipo de medición (si aplica).                                                |                                      |
# | `tot_d`                   | Numérica (Continua)  | Total de la categoría "D" (si aplica).                                       |
# | `tot_v`                   | Numérica (Continua)  | Total de la categoría "V" (si aplica).                                       |
# | `tot_vc`                  | Numérica (Continua)  | Total combinado de las categorías "V" y "C".                                 |
# | `x1_varado`               | Numérica (Continua)  | Métrica específica relacionada con tiempo de inactividad.                    |
# | `nombre_actividad_1`      | Categórica           | Duplicado de `nombre_actividad` (posiblemente redundante).                   |
# | `nombre_actividad_2`      | Categórica           | Duplicado de `nombre_actividad` (posiblemente redundante).                   |
# | `mes_nombre`              | Categórica           | Nombre del mes extraído de `mes`.                                            |
# | `taller_1`                | Categórica           | Duplicado de `taller` (posiblemente redundante).                             |
# | `semana_1`                | Ordinal              | Duplicado de `semana` (posiblemente redundante).                             |
# | `disponibilidad`          | Numérica (Continua)  | Porcentaje de disponibilidad.                                                |
# | `porc_utilizacion`        | Numérica (Continua)  | Porcentaje de utilización (si aplica).                                       |

# %% [markdown]
# **Observación 💡 -->**
# El conjunto de datos contiene múltiples columnas relacionadas con la fecha. Por ello, se llevará a cabo un proceso de preprocesamiento en el que se consolidará toda la información temporal en una única columna, correctamente formateada. Esta estrategia tiene como objetivo reducir la dimensionalidad del conjunto de datos, eliminar redundancias y preservar toda la información relevante para el análisis.

# %%
# Convert the FECHA column to a standard format (YYYY-MM-DD)
df['fecha'] = pd.to_datetime(df['fecha'], format='%d/%m/%Y %H:%M').dt.date

# Drop redundant date-related columns
df = df.drop(columns=['mes', 'mes_nombre'], errors='ignore')

# %% [markdown]
# #### **Frecuencias y Conteo de los Datos**

# %%
# See what are the 10 most frequent values for each of the dataframe columns
for column in df.columns:
    frequency_values = df[column].value_counts().head(10)
    print("Top 10 most frequent values for column '{}':".format(column))
    for index, (value, frequency) in enumerate(frequency_values.items(), start=1):
        print("{:<5} {:<30} {:<10}".format(index, value, frequency))
    print("\n===============================================")
# Out:
# Top 10 most frequent values for column 'c_varado':
#
# ===============================================
# Top 10 most frequent values for column 'causa_varado':
# 1     -                              268425
# 2     INCONVENIENTE TECNICO/TALLER   7982
# 3     MOTOR                          446
# 4     ESPERA INGRESO PREVENTIVO      390
# 5     REPARACION GENERAL             300
# 6     FALTA DE REPUESTOS             241
# 7     PREVENTIVO/TALLER              119
# 8     ACTIVO SIN USO(POCO RECORRIDO) 118
# 9     FALTA TECNICO MECANICO         97
# 10    INCONVENIENTE ELECTRICO/TALLERES 88
#
# ===============================================
# Top 10 most frequent values for column 'cod_actividad':
# 1     4                              152207
# 2     3                              115904
# 3     36                             5240
# 4     37                             2602
# 5     46                             1195
# 6     1                              766
# 7     16                             266
# 8     17                             184
# 9     41                             184
# 10    8                              89
#
# ===============================================
# Top 10 most frequent values for column 'cod_activo':
# 1     16042                          2621
# 2     16142                          2614
# 3     18242                          2602
# 4     30718                          795
# 5     3973                           795
# 6     39618                          795
# 7     39622                          795
# 8     39626                          794
# 9     39617                          794
# 10    39413                          794
#
# ===============================================
# Top 10 most frequent values for column 'cod_categoria':
# 1     294                            56361
# 2     235                            55741
# 3     225                            32038
# 4     396                            25910
# 5     394                            15801
# 6     307                            14065
# 7     245                            12680
# 8     398                            11229
# 9     240                            6046
# 10    360                            6041
#
# ===============================================
# Top 10 most frequent values for column 'cod_correlativo':
# 1     42                             10217
# 2     5                              8363
# 3     1                              8122
# 4     3                              8100
# 5     4                              7734
# 6     2                              7083
# 7     6                              6350
# 8     8                              5916
# 9     22                             5903
# 10    7                              5061
#
# ===============================================
# Top 10 most frequent values for column 'cod_depto':
# 1     19                             43955
# 2     17                             43123
# 3     21                             41622
# 4     23                             35914
# 5     18                             28429
# 6     20                             27659
# 7     22                             18480
# 8     26                             7772
# 9     1                              7406
# 10    24                             3745
#
# ===============================================
# Top 10 most frequent values for column 'cod_epoca':
# 1     1                              278917
#
# ===============================================
# Top 10 most frequent values for column 'cod_labor':
# 1     26                             137744
# 2     22                             113624
# 3     27                             14463
# 4     14                             2621
# 5     10                             2614
# 6     16                             2602
# 7     25                             2280
# 8     70                             1195
# 9     43                             788
# 10    12                             261
#
# ===============================================
# Top 10 most frequent values for column 'cod_periodo':
# 1     45                             64877
# 2     39                             62298
# 3     43                             61647
# 4     41                             61028
# 5     47                             29067
#
# ===============================================
# Top 10 most frequent values for column 'cod_semana':
# 1     1                              12541
# 2     6                              12495
# 3     8                              12393
# 4     3                              12357
# 5     5                              12350
# 6     2                              12336
# 7     10                             12298
# 8     7                              12255
# 9     4                              12235
# 10    9                              12220
#
# ===============================================
# Top 10 most frequent values for column 'cod_taller':
# 1     14                             120657
# 2     15                             118515
# 3     5                              19328
# 4     2                              7842
# 5     6                              5994
# 6     1                              3740
# 7     7                              1989
# 8     3                              667
# 9     9                              89
# 10    4                              61
#
# ===============================================
# Top 10 most frequent values for column 'cod_taller_matriz':
# 1     4.0                            242911
# 2     2.0                            25383
# 3     3.0                            7842
# 4     6.0                            2024
# 5     1.0                            756
#
# ===============================================
# Top 10 most frequent values for column 'correlativo':
# 1     -                              271868
# 2     1                              1349
# 3     2                              717
# 4     3                              634
# 5     4                              606
# 6     5                              575
# 7     6                              560
# 8     7                              542
# 9     8                              467
# 10    9                              442
#
# ===============================================
# Top 10 most frequent values for column 'dias_trab':
# 1     -                              165777
# 2     1                              113139
#
# ===============================================
# Top 10 most frequent values for column 'disp':
# 1     1.0                            267479
# 2     0.0                            1916
# 3     0.7281                         331
# 4     1.0001                         293
# 5     0.9999                         277
# 6     0.9459                         87
# 7     0.9445                         62
# 8     0.9305                         56
# 9     0.9444                         55
# 10    0.9448                         52
#
# ===============================================
# Top 10 most frequent values for column 'epoca':
# 1     ZAFRA                          278916
#
# ===============================================
# Top 10 most frequent values for column 'fecha':
# 1     <30 492
# 2     <30 459
# 3     <30 434
# 4     <30 432
# 5     <30 431
# 6     <30 429
# 7     <30 427
# 8     <30 425
# 9     <30 425
# 10    <30 422
#
# ===============================================
# Top 10 most frequent values for column 'horas_jornada':
# 1     12.0                           244935
# 2     24.0                           33981
#
# ===============================================
# Top 10 most frequent values for column 'kms':
# 1     -                              165777
# 2     20                             6099
# 3     10                             4846
# 4     24                             4687
# 5     12                             4549
# 6     18                             3843
# 7     8                              3757
# 8     6                              3472
# 9     16                             3321
# 10    4                              2556
#
# ===============================================
# Top 10 most frequent values for column 'literal':
# 1     D                              269145
# 2     V                              9771
#
# ===============================================
# Top 10 most frequent values for column 'nombre_actividad':
# 1     EQUIPO DE RIEGO                152206
# 2     TRACTORES                      115904
# 3     JAULAS                         5240
# 4     DOLLIS                         2602
# 5     BOMBAS MOCHILA                 1195
# 6     E. ARRASTRE                    766
# 7     CANA                           266
# 8     S.VARIOS                       184
# 9     PALANGANAS                     184
# 10    BUSES                          89
#
# ===============================================
# Top 10 most frequent values for column 'nombre_depto':
# 1     REGION 3                       43955
# 2     REGION 1                       43123
# 3     REGION 5                       41621
# 4     REGION 7                       35914
# 5     REGION 2                       28429
# 6     REGION 4                       27659
# 7     REGION 6                       18480
# 8     PATIO T.                       7772
# 9     CANA G                         7406
# 10    REGION 0                       3745
#
# ===============================================
# Top 10 most frequent values for column 'nombre_labor':
# 1     MOTO BOMBA                     137743
# 2     TRACTOR AGRICOLA               113624
# 3     PIVOTES / AVANCES              14463
# 4     JAULA 40                       2621
# 5     JAULA MECA                     2614
# 6     DOLLIN 182                     2602
# 7     TRACTOR AGUATERO               2280
# 8     E. FUMIGACION                  1195
# 9     CAMION TALLER                  788
# 10    C.CANERO                       261
#
# ===============================================
# Top 10 most frequent values for column 'nombre_taller':
# 1     TALLER AGRICOLA ESTE           120656
# 2     TALLER AGRICOLA OESTE          118515
# 3     COSECHA GRANEL CANA            19328
# 4     E.ARRASTRE                     7842
# 5     COSECHA MECANIZADA CANA        5994
# 6     AGRICOLA                       3740
# 7     VEHICULOS LIVIANOS             1989
# 8     CAMIONES                       667
# 9     BUSES                          89
# 10    M.PESADA                       61
#
# ===============================================
# Top 10 most frequent values for column 'periodo':
# 1     ZAFRA 22-23                    64877
# 2     ZAFRA 19-20                    62297
# 3     ZAFRA 21-22                    61647
# 4     ZAFRA 20-21                    61028
# 5     ZAFRA 23-24                    29067
#
# ===============================================
# Top 10 most frequent values for column 'semana':
# 1     SEM 1                          12541
# 2     SEM 6                          12495
# 3     SEM 8                          12393
# 4     SEM 3                          12357
# 5     SEM 5                          12350
# 6     SEM 2                          12336
# 7     SEM 10                         12298
# 8     SEM 7                          12255
# 9     SEM 4                          12235
# 10    SEM 9                          12220
#
# ===============================================
# Top 10 most frequent values for column 'taller':
# 1     TALLER AGRICOLA                242911
# 2     TALLER COSECHA/MAQUINARIA PESADA 25383
# 3     TALLER EQUIPO ARRASTRE         7842
# 4     TALLER DE EQUIPO LIVIANO       2024
# 5     TALLER DE LOGISTICA            756
#
# ===============================================
# Top 10 most frequent values for column 'tiempo_varado':
# 1     -                              268424
# 2     2                              4259
# 3     24                             1847
# 4     12                             1213
# 5     1                              819
# 6     4                              216
# 7     23.99                          144
# 8     3                              115
# 9     24.01                          113
# 10    13                             92
#
# ===============================================
# Top 10 most frequent values for column 'tipo_medicion':
# 1     -                              165777
# 2     Horas                          107757
# 3     Kms                            5382
#
# ===============================================
# Top 10 most frequent values for column 'tot_d':
# 1     12.0                           242599
# 2     24.0                           24955
# 3     0.0                            9758
# 4     8.74                           375
# 5     12.01                          267
# 6     11.99                          217
# 7     11.98                          13
# 8     6.0                            11
# 9     23.99                          8
# 10    5.0                            7
#
# ===============================================
# Top 10 most frequent values for column 'tot_v':
# 1     0.0                            268513
# 2     24.0                           7884
# 3     12.0                           1310
# 4     23.99                          203
# 5     24.01                          163
# 6     8.74                           59
# 7     13.0                           40
# 8     11.0                           40
# 9     0.02                           15
# 10    8.73                           13
#
# ===============================================
# Top 10 most frequent values for column 'tot_vc':
# 1     0.0                            268513
# 2     24.0                           7884
# 3     12.0                           1310
# 4     23.99                          203
# 5     24.01                          163
# 6     8.74                           59
# 7     13.0                           40
# 8     11.0                           40
# 9     0.02                           15
# 10    8.73                           13
#
# ===============================================
# Top 10 most frequent values for column 'x1_varado':
# 1     0.0                            268513
# 2     100.0                          1785
# 3     5.41                           74
# 4     5.99                           63
# 5     6.23                           55
# 6     7.56                           53
# 7     7.48                           52
# 8     7.26                           52
# 9     7.64                           52
# 10    6.95                           51
#
# ===============================================
# Top 10 most frequent values for column 'nombre_actividad_1':
# 1     EQUIPO DE RIEGO                152206
# 2     TRACTORES                      115904
# 3     JAULAS                         5240
# 4     DOLLIS                         2602
# 5     BOMBAS MOCHILA                 1195
# 6     E. ARRASTRE                    766
# 7     CANA                           266
# 8     S.VARIOS                       184
# 9     PALANGANAS                     184
# 10    BUSES                          89
#
# ===============================================
# Top 10 most frequent values for column 'nombre_actividad_2':
# 1     EQUIPO DE RIEGO                152206
# 2     TRACTORES                      115904
# 3     JAULAS                         5240
# 4     DOLLIS                         2602
# 5     BOMBAS MOCHILA                 1195
# 6     E. ARRASTRE                    766
# 7     CANA                           266
# 8     S.VARIOS                       184
# 9     PALANGANAS                     184
# 10    BUSES                          89
#
# ===============================================
# Top 10 most frequent values for column 'taller_1':
# 1     TALLER AGRICOLA                242911
# 2     TALLER COSECHA/MAQUINARIA PESADA 25383
# 3     TALLER EQUIPO ARRASTRE         7842
# 4     TALLER DE EQUIPO LIVIANO       2024
# 5     TALLER DE LOGISTICA            756
#
# ===============================================
# Top 10 most frequent values for column 'semana_1':
# 1     SEM 1                          12541
# 2     SEM 6                          12495
# 3     SEM 8                          12393
# 4     SEM 3                          12357
# 5     SEM 5                          12350
# 6     SEM 2                          12336
# 7     SEM 10                         12298
# 8     SEM 7                          12255
# 9     SEM 4                          12235
# 10    SEM 9                          12220
#
# ===============================================
# Top 10 most frequent values for column 'disponibilidad':
# 1     100.0%                         268049
# 2     0.0%                           1916
# 3     72.8%                          333
# 4     94.6%                          230
# 5     93.8%                          217
# 6     94.5%                          211
# 7     93.1%                          209
# 8     92.4%                          206
# 9     92.1%                          198
# 10    93.4%                          196
#
# ===============================================
# Top 10 most frequent values for column 'porc_utilizacion':
# 1     -                              278515
# 2     0                              43
# 3     0.001299101                    1
# 4     0.197136866                    1
# 5     0.202214402                    1
# 6     0.177350453                    1
# 7     0.2675466                      1
# 8     0.324526816                    1
# 9     0.225471386                    1
# 10    0.173573326                    1
#
# ===============================================

# %% [markdown]
# **Observación 💡 -->**
# - La columna `cod_epoca` contiene únicamente un valor, lo que la convierte en una variable constante que no aporta información relevante al conjunto de datos ni al modelo a desarrollar. Por lo tanto, se eliminará.
#
# - De manera similar, la columna `epoca` también posee un único valor, "ZAFRA", lo que la hace redundante y sin valor informativo para el análisis. En consecuencia, esta columna será eliminada.
#
# - La columna `porc_utilizacion` presenta una gran cantidad de valores nulos, lo que limita su utilidad en el análisis. Debido a esto, se procederá a su eliminación.
#
# - Las columnas `semana`, `semana_1` y `cod_semana` son redundantes entre sí, ya que todas contienen información equivalente. Por lo tanto, se optará por consolidarlas en una única columna para reducir la dimensionalidad y evitar duplicación de datos.

# %%
# Drop the 'cod_epoca' column as it contains only one unique value
df.drop(columns=['cod_epoca'], inplace=True)

# Drop the 'epoca' column as it contains only one unique value ("ZAFRA")
df.drop(columns=['epoca'], inplace=True)

# Drop the 'porc_utilizacion' column due to the high number of null values
df.drop(columns=['porc_utilizacion'], inplace=True)

# Drop the redundant columns 'semana' and 'semana_1'
df.drop(columns=['semana', 'semana_1'], inplace=True)

# %% [markdown]
# **Observación 💡 -->**
# Un aspecto crucial identificado en este análisis es la representación inconsistente de los valores nulos o faltantes en el conjunto de datos. Aunque en la mayoría de los casos se utiliza el carácter "-" para representarlos, en otros se emplea directamente `np.nan`. Esta falta de uniformidad dificulta el manejo y análisis de los datos. Por lo tanto, se unificará la representación de los valores faltantes a un formato estándar para garantizar consistencia en el tratamiento de las variables. Posteriormente, se realizará un análisis detallado para calcular el porcentaje de valores faltantes en cada columna, lo que permitirá tomar decisiones informadas sobre su manejo.

# %%
# Replace all instances of '-' with "nan"
df.replace('-', 'nan', inplace=True)
# Replace all instances of np.nan with "nan"
df.replace(np.nan, 'nan', inplace=True)

# %% [markdown]
# #### **Análisis de Datos Faltantes**

# %%
# Replace all instances of '-' with "nan"
df.replace('nan', np.nan, inplace=True)

# %%
# Calculate the percentage of null values in each column
null_percentage = (df.isnull().sum() / len(df)) * 100

# Filter to include only columns with more than 0% null values
null_percentage_filtered = null_percentage[null_percentage > 0]

# Sort the null_percentage Series from highest to lowest
null_percentage_sorted = null_percentage_filtered.sort_values(ascending=False)

# Create a horizontal bar chart
ax = sns.barplot(x=null_percentage_sorted.values, y=null_percentage_sorted.index, hue=null_percentage_sorted.index, dodge=False, palette='viridis')

# Add percentage in each bar
for bar in ax.patches:
    width = bar.get_width()
    ax.text(width,       # X coordinate of text
            bar.get_y() + bar.get_height() / 2,  # Y coordinate of text
            '{:.2f}%'.format(width),  # Text to display (formatted to two decimal places)
            ha='left',  # Horizontal alignment
            va='center',  # Vertical alignment
            color='black',  # Text color
            fontsize=10)  # Font size

plt.xlabel("Porcentaje de Nulos")
plt.ylabel("Columna")
plt.title("Porcentaje de Valores Nulos en Cada Columna")

# Adding grid with custom style
plt.grid(True, linestyle='--', linewidth=0.5)  # Adding grid with dashed lines and custom line width

plt.show()

# %% [markdown]
# **Observación 💡 -->**
# Se identificó la presencia de múltiples columnas con una proporción significativa de valores faltantes, lo que sugiere que estas variables tienen poca o ninguna utilidad para el análisis. En caso de que el objetivo sea entrenar un modelo, se recomienda eliminarlas, ya que no aportan información relevante al conjunto de datos.
#
# Sin embargo, dado que aún no se ha definido el siguiente paso en el procesamiento de este conjunto de datos, se optará por asignar una categoría específica, denominada "Desconocido", a los valores faltantes. Este enfoque garantizará la consistencia en el tratamiento de los datos y facilitará su manejo en etapas posteriores.

# %%
# Replace all np.nan values with "Desconocido"
df.fillna("Desconocido", inplace=True)

# %% [markdown]
# #### **Manejo de Datos Duplicados**

# %%
# Check duplicate rows in dataset
df = df.drop_duplicates()
# Print the number of records in the DataFrame
print("The given dataset has", df.shape[0], "registers and", df.shape[1], "columns.")
# Out:
# The given dataset has 278917 registers and 35 columns.

# %% [markdown]
# **Observación 💡 -->**
# Se ha identificado la presencia de múltiples valores duplicados dentro del conjunto de datos. Este problema puede generar redundancia, distorsionar el análisis exploratorio y afectar negativamente el rendimiento de los modelos desarrollados a partir de estos datos.
#
# **Por lo tanto, se procederá a eliminar las duplicaciones** en este análisis para garantizar la integridad y calidad del conjunto de datos. Aunque esto se hará principalmente para no afectar el análisis exploratorio, se sugiere hacer el mismo proceso para lo que se vaya a hacer posteriormente.
